# %%
import pandas as pd
import numpy as np

# %%
location = "DC_Properties.csv"
df = pd.read_csv(location)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (18,19,20,21,22,23,24,33,34,35,37,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
#        'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID',
#        'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
#        'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
df.groupby(['PRICE', 'BATHRM', 'BEDRM', 'STYLE','FULLADDRESS','WARD']).mean()
# Out:
#                                                                               Unnamed: 0  \
# PRICE      BATHRM BEDRM STYLE           FULLADDRESS                   WARD
# 1.0        1      3     2 Story         4015 21ST STREET NE           Ward 5       81694
#            3      6     3 Story         4734 SOUTH CAPITOL TERRACE SW Ward 8      106683
# 10.0       1      2     2 Story         320 34TH STREET NE            Ward 7       81594
#                   3     2 Story         784 LAMONT STREET NW          Ward 1       51658
#            2      3     2 Story         1101 HOLBROOK TERRACE NE      Ward 5       74419
#                                         3014 Q STREET NW              Ward 2       18568
# 250.0      1      2     2 Story         1249 W STREET SE              Ward 8      102782
#                   3     2 Story         1202 LONGFELLOW STREET NW     Ward 4       50971
#                                         406 BURBANK STREET SE         Ward 7       93541
# ...

# %%
nf = df[['PRICE','BATHRM', 'BEDRM', 'STYLE','FULLADDRESS','WARD']]

# %%
nf.loc[nf['PRICE'] <=800000]
# Out:
#            PRICE  BATHRM  BEDRM    STYLE                   FULLADDRESS    WARD
# 19      592250.0       3      3  2 Story          1735 SWANN STREET NW  Ward 2
# 20       33232.0       3      5  3 Story              1441 Q STREET NW  Ward 2
# 25       20000.0       1      4  2 Story              1451 Q STREET NW  Ward 2
# 27      703700.0       3      3  3 Story       1456 CORCORAN STREET NW  Ward 2
# 32      130500.0       2      2  3 Story       1446 CORCORAN STREET NW  Ward 2
# 37      339500.0       2      4  3 Story       1432 CORCORAN STREET NW  Ward 2
# 45      450000.0       3      5  3 Story       1414 CORCORAN STREET NW  Ward 2
# 48      348500.0       2      3  3 Story       1421 CORCORAN STREET NW  Ward 2
# 54      390000.0       1      2  3 Story       1443 CORCORAN STREET NW  Ward 2
# 55      772500.0       3      3  2 Story       1445 CORCORAN STREET NW  Ward 2
# 58      499000.0       1      1  2 Story          1508 SWANN STREET NW  Ward 2
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
#        'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID',
#        'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
#        'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
bins = [0,20000,300000, 400000, 500000, 600000, 700000,800000000]
group_names = ['Really_Cheap','Cheap','Affordable','Upper_Affordable','Expensive', 'Really_Expensive',"Above_Budget"]
nf['Affordability'] = pd.cut(nf['PRICE'], bins, labels=group_names)
nf.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#        PRICE  BATHRM  BEDRM    STYLE                   FULLADDRESS    WARD  \
# 0  1095000.0       4      4  3 Story          1748 SWANN STREET NW  Ward 2
# 1        NaN       3      5  3 Story          1746 SWANN STREET NW  Ward 2
# 2  2100000.0       3      5  3 Story          1744 SWANN STREET NW  Ward 2
# 3  1602000.0       3      5  3 Story          1742 SWANN STREET NW  Ward 2
# 4        NaN       2      3  3 Story  1804 NEW HAMPSHIRE AVENUE NW  Ward 2
#
#   Cost_of_Housing Affordability
# 0             NaN  Above_Budget
# 1             NaN           NaN
# ...

# %%
nf.groupby(['Affordability','STYLE']).mean()
# Out:
#                                          PRICE    BATHRM     BEDRM
# Affordability    STYLE
# Really_Cheap     1 Story          1.404000e+04  1.200000  2.200000
#                  1.5 Story Fin    1.925000e+04  2.000000  3.000000
#                  1.5 Story Unfin           NaN       NaN       NaN
#                  2 Story          9.046060e+03  1.807229  3.156627
#                  2.5 Story Fin    8.896667e+03  2.333333  4.333333
#                  2.5 Story Unfin           NaN       NaN       NaN
#                  3 Story          8.126250e+02  3.000000  5.000000
#                  3.5 Story Fin             NaN       NaN       NaN
#                  3.5 Story Unfin           NaN       NaN       NaN
#                  4 Story                   NaN       NaN       NaN
#                  4.5 Story Fin             NaN       NaN       NaN
#                  4.5 Story Unfin           NaN       NaN       NaN
#                  Bi-Level                  NaN       NaN       NaN
# ...
